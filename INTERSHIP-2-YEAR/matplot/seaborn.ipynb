# %% [markdown]
# SEABORN

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = sns.load_dataset("tips")

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.plot(data['total_bill'])
plt.show()

# %%
sns.lineplot(data['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.scatterplot(x='total_bill',y='tip',data=data)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.hist()
#
# File c:\Users\jangi\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# TypeError: hist() missing 1 required positional argument: 'x'

# %%
sns.kdeplot(data)
# Out:
# <Axes: ylabel='Density'>

# %%
# catplot
# relplot

# %%
sns.relplot(x='total_bill',y='tip',data=data)

# %%
sns.relplot(x='total_bill',y='tip',hue='time',data=data)

# %%
sns.relplot(x='total_bill',y='tip',hue='time',style='smoker',kind='scatter',col="smoker",data=data)

# %%
sns.relplot(x='total_bill',y='tip',hue='time',style='smoker',kind='scatter',col="day",data=data)

# %%
sns.relplot(y='total_bill',x='tip',data=data)
plt.title("this is relplot")
plt.xlabel("Total_bill",fontsize=20,color="black")
plt.ylabel("Tip",font=20,color="pink")
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 plt.title("this is relplot")
#       3 plt.xlabel("Total_bill",fontsize=20,color="black")
# ----> 4 plt.ylabel("Tip",font=20,color="pink")
#       5 plt.show
#
# File c:\Users\jangi\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:4422, in ylabel(ylabel, fontdict, labelpad, loc, **kwargs)
#    4413 @_copy_docstring_and_deprecators(Axes.set_ylabel)
#    4414 def ylabel(
#    4415     ylabel: str,
#    (...)   4420     **kwargs,
#    4421 ) -> Text:
# -> 4422     return gca().set_ylabel(
#    4423         ylabel, fontdict=fontdict, labelpad=labelpad, loc=loc, **kwargs
#    4424     )
#
# File c:\Users\jangi\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:3888, in _AxesBase.set_ylabel(self, ylabel, fontdict, labelpad, loc, **kwargs)
#    3881     y, ha = {
#    3882         'bottom': (0, 'left'),
#    3883         'center': (0.5, 'center'),
#    3884         'top': (1, 'right')
#    3885     }[loc]
#    3886     kwargs.update(y=y, horizontalalignment=ha)
# -> 3888 return self.yaxis.set_label_text(ylabel, fontdict, **kwargs)
#
# File c:\Users\jangi\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:1902, in Axis.set_label_text(self, label, fontdict, **kwargs)
#    1900 if fontdict is not None:
#    1901     self.label.update(fontdict)
# -> 1902 self.label.update(kwargs)
#    1903 self.stale = True
#    1904 return self.label
#
# File c:\Users\jangi\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\text.py:202, in Text.update(self, kwargs)
#     200 fontproperties = kwargs.pop("fontproperties", sentinel)
#     201 if fontproperties is not sentinel:
# --> 202     ret.append(self.set_fontproperties(fontproperties))
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
#
# File c:\Users\jangi\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\text.py:1327, in Text.set_fontproperties(self, fp)
#    1316 def set_fontproperties(self, fp):
#    1317     """
#    1318     Set the font properties that control the text.
#    1319
#    (...)   1325         absolute path to a font file.
#    1326     """
# -> 1327     self._fontproperties = FontProperties._from_any(fp).copy()
#    1328     self.stale = True
#
# File c:\Users\jangi\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\font_manager.py:698, in FontProperties._from_any(cls, arg)
#     696     return cls(arg)
#     697 else:
# --> 698     return cls(**arg)
#
# TypeError: matplotlib.font_manager.FontProperties() argument after ** must be a mapping, not int

# %% [markdown]
# CATPLOT

# %%
sns.catplot(x='day',y='total_bill',kind='swarm',data=data)

# %%
sns.catplot(x='day',y='total_bill',kind='strip',data=data)

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=data)

# %%
sns.catplot(x='day',y='total_bill',kind='bar',data=data)

# %%
sns.catplot(x='day',y='total_bill',kind='violin',data=data)

# %%
sns.catplot(x='day',y='total_bill',kind='boxen',data=data)

# %% [markdown]
# count plot

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='day',data=data)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# boxplot

# %%
sns.boxplot(x='day',y='total_bill',data=data)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(y='total_bill',data=data)
# Out:
# <Axes: ylabel='total_bill'>
